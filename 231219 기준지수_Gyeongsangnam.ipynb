# %%
import requests
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

import numpy as np
import pandas as pd

# %%
Gyeongsangnam = pd.read_csv('mini_project_1/Jeju.csv')
Gyeongsangnam
# Out:
#      Unnamed: 0      업종     업소명    주요품목      가격             연락처  \
# 0             0   한식_면류   아줌마우동   우동(소)   4000원    055-354-7510
# 1             1   한식_분식     굴림당      만두   5000원   010-3734-3373
# 2             2   한식_일반     영남멘      라멘   8900원   010-3734-3373
# 3             3    이미용업  살롱드 해미    남성커트  13000원  0507-1356-7079
# 4             4  한식_해산물    성포횟집  모둠회(소)  60000원    055-642-9910
# ..          ...     ...     ...     ...     ...             ...
# 414         414   한식_일반    대구분식     비빔밥   5000원    055-944-4177
# 415         415   한식_일반    제일분식     칼국수   4000원    055-942-8928
# 416         416   한식_일반    봉천식당    된장찌개   7000원    055-944-5316
# 417         417    이미용업    맨인그린      커트   7000원    055-633-8533
# 418         418      일식    어부횟집    구이정식   9000원    055-635-3688
#
#                                     주소
# 0                  경상남도 밀양시 중앙로 289-24
# 1           경상남도 밀양시 밀양시 남천강변로 3길 7 1층
# 2    경상남도 밀양시 밀양시 상설시장 1길 11 207호~214호
# ...

# %%
Gyeongsangnam.drop('Unnamed: 0',axis = 1, inplace = True)

Gyeongsangnam['주소_구,군'] = Gyeongsangnam['주소'].apply(lambda x:x.split(' ')[0])

Gyeongsangnam['주소_구,군'] = Gyeongsangnam['주소'].apply(lambda x:x.replace('\xa0',' '))
Gyeongsangnam['keyword'] = Gyeongsangnam['주소_구,군']

Gyeongsangnam_address_list = Gyeongsangnam['keyword'].apply(lambda x:x.split(' '))

new_Gyeongsangnam_address_list = []

for i,item in enumerate(Gyeongsangnam_address_list):
    #print(ad_li[i][:2])
    address = item[0] + ' ' + item[1]
    new_Gyeongsangnam_address_list.append(address)
    
new_Gyeongsangnam_address_list

Gyeongsangnam['keyword'] = new_Gyeongsangnam_address_list

Gyeongsangnam['keyword'] = Gyeongsangnam['keyword'] + ' ' + Gyeongsangnam['업소명']

# %%
# 카카오맵 url 가져오기
url = 'https://map.kakao.com/'

# 크롬 드라이버 실행하기
driver = webdriver.Chrome()

# 카카오맵 url로 이동하기
driver.get(url)

score_list = []

for key in Gyeongsangnam['keyword'][:419]:
    # 검색창 클릭하기
    search = driver.find_element(By.CSS_SELECTOR, '#search\.keyword\.query')

    # keyword의 key를 검색창에 넣기
    search.send_keys(key)

    # 엔터키로 이동하기
    search.send_keys(Keys.RETURN)

    time.sleep(2)

    # 웹 스크립트 받아오기
    html = driver.page_source

    # 웹스크립트에서 원하는 콘텐츠 추출하기 - parsing
    soup = BeautifulSoup(html, 'html.parser')
    
    # keyword별 평점 가져오기
    try:
        # 평점 path 가져오기
        score_path = '#info\.search\.place\.list > li:nth-child(1) > div.rating.clickArea'
        
        # score_path를 split한 후 3번째 문자 추출하기
        score = soup.select(score_path)[0].text.split('\n')[3]
        
        # 평점을 빈 리스트 L에 추가하기
        score_list.append(score)
        
    except:
        score_list.append('별점 없음')
        
    search.clear()
    
score_list

Gyeongsangnam['평점'] = score_list
Gyeongsangnam.drop('주소_구,군',axis = 1, inplace = True)
Gyeongsangnam.drop('keyword',axis = 1, inplace = True)
Gyeongsangnam.to_csv('Gyeongsangnamscore.csv', encoding='utf-8-sig')
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:33: SyntaxWarning: invalid escape sequence '\.'
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:33: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\vvv\AppData\Local\Temp\ipykernel_13260\4102638878.py:14: SyntaxWarning: invalid escape sequence '\.'
#   search = driver.find_element(By.CSS_SELECTOR, '#search\.keyword\.query')
# C:\Users\vvv\AppData\Local\Temp\ipykernel_13260\4102638878.py:33: SyntaxWarning: invalid escape sequence '\.'
#   score_path = '#info\.search\.place\.list > li:nth-child(1) > div.rating.clickArea'

# %%
Gyeongsangnam
# Out:
#          업종     업소명    주요품목      가격             연락처  \
# 0     한식_면류   아줌마우동   우동(소)   4000원    055-354-7510
# 1     한식_분식     굴림당      만두   5000원   010-3734-3373
# 2     한식_일반     영남멘      라멘   8900원   010-3734-3373
# 3      이미용업  살롱드 해미    남성커트  13000원  0507-1356-7079
# 4    한식_해산물    성포횟집  모둠회(소)  60000원    055-642-9910
# ..      ...     ...     ...     ...             ...
# 414   한식_일반    대구분식     비빔밥   5000원    055-944-4177
# 415   한식_일반    제일분식     칼국수   4000원    055-942-8928
# 416   한식_일반    봉천식당    된장찌개   7000원    055-944-5316
# 417    이미용업    맨인그린      커트   7000원    055-633-8533
# 418      일식    어부횟집    구이정식   9000원    055-635-3688
#
#                                     주소                             주소_구,군  \
# 0                  경상남도 밀양시 중앙로 289-24                경상남도 밀양시 중앙로 289-24
# 1           경상남도 밀양시 밀양시 남천강변로 3길 7 1층         경상남도 밀양시 밀양시 남천강변로 3길 7 1층
# 2    경상남도 밀양시 밀양시 상설시장 1길 11 207호~214호  경상남도 밀양시 밀양시 상설시장 1길 11 207호~214호
# ...
